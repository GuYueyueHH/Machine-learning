# %%
import pandas as pd
train = pd.read_csv('../datasets/breast-cancer-train.csv', usecols=['Clump Thickness', 'Cell Size', 'Type'])
X_train = train[['Clump Thickness', 'Cell Size']]
y_train = train[['Type']]

test = pd.read_csv('../datasets/breast-cancer-test.csv', usecols=['Clump Thickness', 'Cell Size', 'Type'])
X_test = test[['Clump Thickness', 'Cell Size']]
y_test = test[['Type']]

test_negative = test.loc[test['Type'] == 0][['Clump Thickness', 'Cell Size', 'Type']]
test_positive = test.loc[test['Type'] == 1][['Clump Thickness', 'Cell Size', 'Type']]

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.dpi'] = 300 

plt.scatter(test_negative['Clump Thickness'],test_negative['Cell Size'], marker = 'o', s=200, c='green', label='benign')
plt.scatter(test_positive['Clump Thickness'],test_positive['Cell Size'], marker = 'x', s=200, c='red', label='malignant')
plt.xlabel('Clump Thickness')
plt.ylabel('Cell Size')
plt.legend()
plt.show()

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

lr = LogisticRegression()

lr.fit(X_train, y_train)

y_predict = lr.predict(X_test)

accuracy_score(y_test, y_predict)
# Out:
# /Users/michael/anaconda/lib/python2.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/michael/anaconda/lib/python2.7/site-packages/sklearn/utils/validation.py:752: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.9371428571428572

# %%
import numpy as np

lx = np.arange(0, 12)
ly = (-lr.intercept_ - lx * lr.coef_[0,0]) / lr.coef_[0,1]

# %%
plt.plot(lx, ly, c='black')
plt.scatter(test_negative['Clump Thickness'],test_negative['Cell Size'], marker = 'o', s=200, c='green', label='benign')
plt.scatter(test_positive['Clump Thickness'],test_positive['Cell Size'], marker = 'x', s=200, c='red', label='malignant')
plt.xlabel('Clump Thickness')
plt.ylabel('Cell Size')
plt.legend()
plt.show()

# %%
lr = LogisticRegression()

lr.fit(X_train[:10], y_train[:10])

y_predict = lr.predict(X_test)

accuracy_score(y_test, y_predict)
# Out:
# 0.8685714285714285

# %%
lx = np.arange(0, 12)
ly = (-lr.intercept_ - lx * lr.coef_[0,0]) / lr.coef_[0,1]
plt.plot(lx, ly, c='black')
plt.scatter(test_negative['Clump Thickness'],test_negative['Cell Size'], marker = 'o', s=200, c='green', label='benign')
plt.scatter(test_positive['Clump Thickness'],test_positive['Cell Size'], marker = 'x', s=200, c='red', label='malignant')
plt.xlabel('Clump Thickness')
plt.ylabel('Cell Size')
plt.legend()
plt.show()

# %%
# 利用numpy中的random函数随机采样直线的截距和系数。
intercept = np.random.random([1])
coef = np.random.random([1,2])

# %%
lr.intercept_ = intercept
lr.coef = coef

# %%
y_predict = lr.predict(X_test)

accuracy_score(y_test, y_predict)
# Out:
# 0.32571428571428573

# %%
lx = np.arange(0, 12)
ly = (-lr.intercept_ - lx * lr.coef_[0,0]) / lr.coef_[0,1]
plt.plot(lx, ly, c='black')
plt.scatter(test_negative['Clump Thickness'],test_negative['Cell Size'], marker = 'o', s=200, c='green', label='benign')
plt.scatter(test_positive['Clump Thickness'],test_positive['Cell Size'], marker = 'x', s=200, c='red', label='malignant')
plt.xlabel('Clump Thickness')
plt.ylabel('Cell Size')
plt.legend()
plt.show()
